# %%
# Importing libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler

# %%
# Loading and reading the dataset
df = pd.read_csv(r'C:\Users\User\Downloads\crimedata.csv.zip')

# %%
crimedata = pd.read_csv(r"C:\Users\User\Downloads\crimedata.csv.zip")

# %%
# To see the first 5 rows of the dataset
df.head()
# Out:
#              communityName state  countyCode  communityCode  population  \
# 0  BerkeleyHeightstownship    NJ        39.0         5320.0       11980
# 1           Marpletownship    PA        45.0        47616.0       23123
# 2               Tigardcity    OR         NaN            NaN       29344
# 3         Gloversvillecity    NY        35.0        29443.0       16656
# 4              Bemidjicity    MN         7.0         5068.0       11245
#
#    householdsize  racepctblack  racePctWhite  racePctAsian  racePctHisp  ...  \
# 0           3.10          1.37         91.78          6.50         1.88  ...
# 1           2.82          0.80         95.57          3.44         0.85  ...
# 2           2.43          0.74         94.33          3.43         2.35  ...
# 3           2.40          1.70         97.35          0.50         0.70  ...
# 4           2.76          0.53         89.16          1.17         0.52  ...
#
# ...

# %%
# To see the last 5 rows of the dataset
crimedata.tail()
# Out:
#            communityName state  countyCode  communityCode  population  \
# 2210          Mercedcity    CA         NaN            NaN       56216
# 2211       Pinevillecity    LA         NaN            NaN       12251
# 2212         Yucaipacity    CA         NaN            NaN       32824
# 2213        Beevillecity    TX         NaN            NaN       13547
# 2214  WestSacramentocity    CA         NaN            NaN       28898
#
#       householdsize  racepctblack  racePctWhite  racePctAsian  racePctHisp  \
# 2210           3.07          6.87         61.68         15.23        29.86
# 2211           2.68         21.18         76.65          1.52         1.29
# 2212           2.46          0.52         92.62          0.98        11.00
# 2213           2.89          3.37         69.91          0.90        62.11
# 2214           2.61          2.39         71.27          9.09        24.43
#
#       ...  burglaries  burglPerPop  larcenies  larcPerPop  autoTheft  \
# ...

# %%
crimedata.shape
# Out:
# (2215, 146)

# %%
# To see the information of the data
crimedata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2215 entries, 0 to 2214
# Columns: 146 entries, communityName to nonViolPerPop
# dtypes: float64(116), int64(28), object(2)
# memory usage: 2.5+ MB

# %%
df.describe()
# Out:
#          population  autoTheftPerPop    arsons  arsonsPerPop  \
# count      5.000000          5.00000   5.00000      5.000000
# mean   28747.200000        586.55400  13.00000     33.668000
# std    17849.010524        502.25816  13.96424     25.763552
# min    12251.000000        102.10000   1.00000      7.850000
# 25%    13547.000000        198.56000   2.00000     16.550000
# 50%    28898.000000        487.19000   8.00000     21.770000
# 75%    32824.000000        806.25000  20.00000     56.060000
# max    56216.000000       1338.67000  34.00000     66.110000
#
#        ViolentCrimesPerPop  nonViolPerPop
# count             5.000000       5.000000
# mean            526.748000  152068.402000
# std             305.449286  326254.955164
# min             124.100000    4654.200000
# 25%             353.830000    5340.870000
# 50%             545.750000    5824.440000
# 75%             691.170000    8838.500000
# max             918.890000  735684.000000

# %%
# Checking for missing values

df.isnull().sum()
# Out:
# communityName             0
# state                     0
# countyCode             1221
# communityCode          1224
# population                0
#                        ...
# autoTheftPerPop           3
# arsons                   91
# arsonsPerPop             91
# ViolentCrimesPerPop     221
# nonViolPerPop            97
# Length: 146, dtype: int64

# %%
# Finding duplicates
df.duplicated().sum()
# Out:
# 0

# %%
df.describe()
# Out:
#        countyCode  communityCode    population  householdsize  racepctblack  \
# count  994.000000     991.000000  2.215000e+03    2215.000000   2215.000000
# mean    65.587525   45209.251261  5.311798e+04       2.707327      9.335102
# std    117.831399   25425.861573  2.046203e+05       0.334120     14.247156
# min      1.000000      70.000000  1.000500e+04       1.600000      0.000000
# 25%     11.000000   22887.000000  1.436600e+04       2.500000      0.860000
# 50%     27.000000   46925.000000  2.279200e+04       2.660000      2.870000
# 75%     80.500000   65805.000000  4.302400e+04       2.850000     11.145000
# max    840.000000   94597.000000  7.322564e+06       5.280000     96.670000
#
#        racePctWhite  racePctAsian  racePctHisp  agePct12t21  agePct12t29  ...  \
# count   2215.000000   2215.000000  2215.000000  2215.000000  2215.000000  ...
# mean      83.979819      2.670203     7.950176    14.445837    27.644840  ...
# ...

# %%
# In order to transform the described data

df.describe().T
# Out:
#                       count          mean            std       min  \
# countyCode            994.0     65.587525     117.831399      1.00
# communityCode         991.0  45209.251261   25425.861573     70.00
# population           2215.0  53117.984199  204620.252853  10005.00
# householdsize        2215.0      2.707327       0.334120      1.60
# racepctblack         2215.0      9.335102      14.247156      0.00
# ...                     ...           ...            ...       ...
# autoTheftPerPop      2212.0    473.965628     504.666026      6.55
# arsons               2124.0     30.907721     180.125248      0.00
# arsonsPerPop         2124.0     32.153682      39.240900      0.00
# ViolentCrimesPerPop  1994.0    589.078922     614.784518      0.00
# nonViolPerPop        2118.0   4908.241804    2739.708901    116.79
#
#                             25%        50%         75%         max
# countyCode              11.0000     27.000     80.5000      840.00
# ...

# %%
df.describe(include="object")
# Out:
#        communityName state
# count           2215  2215
# unique          2018    48
# top       Auburncity    CA
# freq               5   279

# %%
# Understanding the data using a histogram
   
for i in df.select_dtypes

# %%
# Handling missing values
df = pd.DataFrame({
    'communityName': ['Mercedcity', 'Pinevillecity', 'Yucaicity', 'Beevillecity', 'WestSacramentocity'],
    'state': ['CA', 'LA', 'CA', 'TX', 'CA'],
    'countyCode': [1, 2, np.nan, 4, 5],
    'communityCode': [np.nan, np.nan, np.nan, np.nan, np.nan],
    'population': [56216, 12251, 32824, 13547, 28898],
    'autoTheftPerPop': [806.25, 198.56, 487.19, 102.10, 1338.67],
    'arsons': [34.0, 2.0, 8.0, 1.0, 20.0],
    'arsonsPerPop': [56.06, 16.55, 21.77, 7.85, 66.11],
    'ViolentCrimesPerPop': [545.75, 124.10, 353.83, 691.17, 918.89],
    'nonViolPerPop': [735684, 5824.44, 4654.20, 5340.87, 8838.50]
})

# %%
# To drop columns with missing values
df.drop(columns=['countyCode', 'communityCode'], inplace=True)

# %%
df
# Out:
#         communityName state  population  autoTheftPerPop  arsons  \
# 0          Mercedcity    CA       56216           806.25    34.0
# 1       Pinevillecity    LA       12251           198.56     2.0
# 2           Yucaicity    CA       32824           487.19     8.0
# 3        Beevillecity    TX       13547           102.10     1.0
# 4  WestSacramentocity    CA       28898          1338.67    20.0
#
#    arsonsPerPop  ViolentCrimesPerPop  nonViolPerPop
# 0         56.06               545.75      735684.00
# 1         16.55               124.10        5824.44
# 2         21.77               353.83        4654.20
# 3          7.85               691.17        5340.87
# 4         66.11               918.89        8838.50

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.histplot(['numerical_feature1'], kde=True)
plt.title('Correlation matrix')
plt.show()
